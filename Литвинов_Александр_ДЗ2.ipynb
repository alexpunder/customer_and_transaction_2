# %% [markdown]
# ## Шаг 1. Создание таблиц с перечисленными структурами
#
# ![Итоговый вид таблиц](tables.png)
#
# ![Примеры загруженных данных](data_tables_examples.png)

# %% [markdown]
# ## Шаг 2. Подготовка окружения и создание подключения

# %%
# %pip install "psycopg[binary]"
# Out:
# Requirement already satisfied: psycopg[binary] in ./venv/lib/python3.12/site-packages (3.2.13)
# Requirement already satisfied: typing-extensions>=4.6 in ./venv/lib/python3.12/site-packages (from psycopg[binary]) (4.15.0)
# Requirement already satisfied: psycopg-binary==3.2.13 in ./venv/lib/python3.12/site-packages (from psycopg[binary]) (3.2.13)
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg

from psycopg.rows import TupleRow

# %%
connection = psycopg.connect(
    dbname="hw_2",
    user="postgres",
    password="1234qaz",
    host="localhost",
    port="5432",
)

cur = connection.cursor()

def resalt_output(records: list[TupleRow]) -> None:
    """Вывод информации о записях БД."""
    if not records:
        print("Запрос не дал результатов.")
    else:
        for i, row in enumerate(records):
            print(f"Вывод строки #{i+1}: {row}")

# %% [markdown]
# ## Шаг 3. Выполнение запросов

# %% [markdown]
# 1. Вывести все уникальные бренды, у которых есть хотя бы один продукт со стандартной стоимостью выше 1500 долларов, и суммарными продажами не менее 1000 единиц.

# %%
query_1 = """
    SELECT DISTINCT p.brand
    FROM product p
    WHERE p.standard_cost > 1500
        AND p.product_id IN (
            SELECT oi.product_id 
            FROM order_items oi 
            GROUP BY oi.product_id 
            HAVING SUM(oi.quantity) >= 1000
        );
"""

cur.execute(query_1)

resalt_output(cur.fetchall())
# Out:
# Вывод строки #1: ('Giant Bicycles',)
# Вывод строки #2: ('OHM Cycles',)

# %% [markdown]
# 2. Для каждого дня в диапазоне с 2017-04-01 по 2017-04-09 включительно вывести количество подтвержденных онлайн-заказов и количество уникальных клиентов, совершивших эти заказы.

# %%
query_2 = """
    SELECT 
        o.order_date,
        COUNT(o.order_id) AS order_count,
        COUNT(DISTINCT o.customer_id) AS customers_count
    FROM orders o 
    WHERE o.online_order IS TRUE
        AND o.order_status = 'Approved'
        AND o.order_date BETWEEN '2017-04-01' AND '2017-04-09'
    GROUP BY o.order_date;
"""

cur.execute(query_2)

resalt_output(cur.fetchall())
# Out:
# Вывод строки #1: (datetime.date(2017, 4, 1), 37, 37)
# Вывод строки #2: (datetime.date(2017, 4, 2), 29, 29)
# Вывод строки #3: (datetime.date(2017, 4, 3), 27, 27)
# Вывод строки #4: (datetime.date(2017, 4, 4), 32, 32)
# Вывод строки #5: (datetime.date(2017, 4, 5), 33, 32)
# Вывод строки #6: (datetime.date(2017, 4, 6), 36, 36)
# Вывод строки #7: (datetime.date(2017, 4, 7), 24, 24)
# Вывод строки #8: (datetime.date(2017, 4, 8), 33, 33)
# Вывод строки #9: (datetime.date(2017, 4, 9), 30, 30)

# %% [markdown]
# 3. Вывести профессии клиентов:
#  - из сферы IT, чья профессия начинается с Senior;
#  - из сферы Financial Services, чья профессия начинается с Lead.
#
# Для обеих групп учитывать только клиентов старше 35 лет. Объединить выборки с помощью UNION ALL.

# %%
query_3 = """
    SELECT 
        c.first_name
        ,c.last_name
        ,c.job_title 
    FROM customer c 
    WHERE c.job_industry_category = 'IT'
        AND c.job_title LIKE 'Senior%'
        AND c.dob IS NOT NULL
        AND AGE(CURRENT_DATE, c.dob) > INTERVAL '35 years'

    UNION ALL

    SELECT 
        c2.first_name
        ,c2.last_name
        ,c2.job_title 
    FROM customer c2
    WHERE c2.job_industry_category = 'Financial Services'
        AND c2.job_title LIKE 'Lead%'
        AND c2.dob IS NOT NULL
        AND AGE(CURRENT_DATE, c2.dob) > INTERVAL '35 years';
"""

cur.execute(query_3)

resalt_output(cur.fetchall())
# Out:
# Вывод строки #1: ('Valaria', 'Hugh', 'Senior Sales Associate')
# Вывод строки #2: ('Laureen', 'Blower', 'Senior Developer')

# %% [markdown]
# 4. Вывести бренды, которые были куплены клиентами из сферы Financial Services, но не были куплены клиентами из сферы IT.

# %%
query_4 = """
    SELECT DISTINCT p.brand 
    FROM orders o 
    JOIN customer c ON o.customer_id = c.customer_id 
    JOIN order_items oi ON o.order_id = oi.order_id 
    JOIN product p ON oi.product_id = p.product_id 
    WHERE c.job_industry_category = 'Financial Services'

    except

    SELECT DISTINCT p.brand 
    FROM orders o 
    JOIN customer c ON o.customer_id = c.customer_id 
    JOIN order_items oi ON o.order_id = oi.order_id 
    JOIN product p ON oi.product_id = p.product_id 
    WHERE c.job_industry_category = 'IT';
"""

cur.execute(query_4)

resalt_output(cur.fetchall())
# Out:
# Запрос не дал результатов.

# %% [markdown]
# 5. Вывести 10 клиентов (ID, имя, фамилия), которые совершили наибольшее количество онлайн-заказов (в штуках) брендов Giant Bicycles, Norco Bicycles, Trek Bicycles, при условии, что они активны и имеют оценку имущества (property_valuation) выше среднего среди клиентов из того же штата.

# %%
query_5 = """
    SELECT 
        c.customer_id
        ,c.first_name
        ,c.last_name
        ,COUNT(DISTINCT o.order_id) AS orders_count
    FROM customer c 
    JOIN orders o ON c.customer_id = o.customer_id 
    JOIN order_items oi ON o.order_id = oi.order_id 
    JOIN product p ON oi.product_id = p.product_id 
    WHERE o.online_order IS TRUE
        AND p.brand IN ('Giant Bicycles', 'Norco Bicycles', 'Trek Bicycles')
        AND c.deceased_indicator = 'N'
        AND c.property_valuation > (
            SELECT AVG(c2.property_valuation)
            FROM customer c2
            WHERE c2.state = c.state 
        )
    GROUP BY c.customer_id, c.first_name, c.last_name
    ORDER BY orders_count DESC
    LIMIT 10;
"""

cur.execute(query_5)

resalt_output(cur.fetchall())
# Out:
# Вывод строки #1: (353, 'Antonia', 'Cardis', 7)
# Вывод строки #2: (3221, 'Brigid', 'Quigley', 7)
# Вывод строки #3: (1302, 'Ericka', 'Eggers', 6)
# Вывод строки #4: (534, 'Madel', 'Palffrey', 6)
# Вывод строки #5: (787, 'Norma', 'Batrim', 6)
# Вывод строки #6: (1117, 'Georgena', 'Guilaem', 6)
# Вывод строки #7: (25, 'Geoff', 'Assaf', 6)
# Вывод строки #8: (1, 'Laraine', 'Medendorp', 6)
# Вывод строки #9: (478, 'Darcey', 'Harberer', 6)
# Вывод строки #10: (714, 'Burtie', 'Scintsbury', 6)

# %% [markdown]
# 6. Вывести всех клиентов (ID, имя, фамилия), у которых нет подтвержденных онлайн-заказов за последний год, но при этом они владеют автомобилем и их сегмент благосостояния не Mass Customer.

# %%
query_6 = """
    WITH last_year_approved_orders AS (
        SELECT DISTINCT customer_id
        FROM orders
        WHERE online_order IS TRUE
            AND order_status = 'Approved'
            AND order_date >= CURRENT_DATE - INTERVAL '1 year'
    )
    SELECT
        c.customer_id
        ,c.first_name
        ,c.last_name
    FROM customer c 
    WHERE c.customer_id NOT IN (
        SELECT customer_id
        FROM last_year_approved_orders
    )
        AND c.owns_car = 'Yes'
        AND c.wealth_segment != 'Mass Customer';
"""

cur.execute(query_6)

resalt_output(cur.fetchall())
# Out:
# Вывод строки #1: (318, 'Libbie', 'Castelin')
# Вывод строки #2: (1233, 'Keeley', 'Hawsby')
# Вывод строки #3: (2538, 'Jacinta', 'Petrillo')
# Вывод строки #4: (3558, 'Torey', 'Sarney')
# Вывод строки #5: (5, 'Sheila-kathryn', 'Calton')
# Вывод строки #6: (6, 'Curr', 'Duckhouse')
# Вывод строки #7: (7, 'Fina', 'Merali')
# Вывод строки #8: (9, 'Mala', 'Lind')
# Вывод строки #9: (13, 'Gabriele', 'Norcross')
# Вывод строки #10: (17, 'Heath', 'Faraday')
# Вывод строки #11: (21, 'Mile', 'Cammocke')
# Вывод строки #12: (23, 'Olav', 'Polak')
# Вывод строки #13: (28, 'Fee', 'Zellmer')
# Вывод строки #14: (30, 'Darrick', 'Helleckas')
# Вывод строки #15: (31, 'Star', 'Praton')
# Вывод строки #16: (33, 'Ernst', 'Hacon')
# Вывод строки #17: (35, 'Margaretha', 'Strettle')
# Вывод строки #18: (44, 'Neron', 'Verick')
# Вывод строки #19: (46, 'Kaila', 'Allin')
# Вывод строки #20: (55, 'Linc', 'Jillions')
# Вывод строки #21: (58, 'Dalenna', 'Pinnock')
# Вывод строки #22: (65, 'Yale', 'Tanser')
# Вывод строки #23: (71, 'Hoyt', 'Glavias')
# Вывод строки #24: (72, 'Sammy', 'Cheese')
# Вывод строки #25: (73, 'Minette', 'Worters')
# Вывод строки #26: (76, 'Rea', 'Hasser')
# Вывод строки #27: (86, 'Job', 'Sleney')
# Вывод строки #28: (88, 'Malynda', 'Tumber')
# Вывод строки #29: (91, 'Dylan', 'Meaker')
# Вывод строки #30: (95, 'Nomi', 'Mallinder')
# Вывод строки #31: (103, 'Ethyl', 'Runham')
# Вывод строки #32: (106, 'Glyn', '')
# Вывод строки #33: (109, 'Cody', 'Blabey')
# Вывод строки #34: (116, 'Scottie', 'Swiffen')
# Вывод строки #35: (119, 'Willey', 'Chastanet')
# Вывод строки #36: (120, 'Sloan', 'Wagg')
# Вывод строки #37: (124, 'Kath', 'Cunney')
# Вывод строки #38: (129, 'Weidar', 'Silkstone')
# Вывод строки #39: (134, 'Merna', 'McCulloch')
# Вывод строки #40: (136, 'Mel', 'Bennet')
# Вывод строки #41: (138, 'Onofredo', 'Franc')
# Вывод строки #42: (141, 'Townsend', 'Trobe')
# Вывод строки #43: (163, 'Kessia', 'Helder')
# Вывод строки #44: (164, 'Aarika', 'Van Vuuren')
# Вывод строки #45: (167, 'Nathalie', 'Tideswell')
# Вывод строки #46: (169, 'Alfy', 'Bruhnke')
# Вывод строки #47: (172, 'Hilton', 'Carney')
# Вывод строки #48: (179, 'Esteban', 'Sewill')
# Вывод строки #49: (182, 'Lydon', 'Dahlman')
# Вывод строки #50: (184, 'Nappie', 'Paolo')
# Вывод строки #51: (188, 'Audry', 'Seine')
# Вывод строки #52: (191, 'Christopher', 'Heining')
# Вывод строки #53: (200, 'Hube', 'Weald')
# Вывод строки #54: (202, 'Audie', 'Pillinger')
# Вывод строки #55: (209, 'Udall', 'Bellard')
# Вывод строки #56: (213, 'Lockwood', 'Exroll')
# Вывод строки #57: (215, 'Debera', 'Foxworthy')
# Вывод строки #58: (216, 'Cinderella', 'Parcall')
# Вывод строки #59: (218, 'Stefa', 'Dunnan')
# Вывод строки #60: (223, 'Ossie', 'Meaton')
# Вывод строки #61: (237, 'Reginald', 'Dartan')
# Вывод строки #62: (240, 'Gavin', 'Fawks')
# Вывод строки #63: (243, 'Barbara', 'Croxley')
# Вывод строки #64: (247, 'Kristal', 'Joysey')
# Вывод строки #65: (248, 'Inger', 'Eskell')
# Вывод строки #66: (251, 'Mala', '')
# Вывод строки #67: (256, 'Linell', 'Beadle')
# Вывод строки #68: (257, 'Marissa', '')
# Вывод строки #69: (259, 'Venita', 'Dymick')
# Вывод строки #70: (260, 'Farand', 'Marriner')
# Вывод строки #71: (262, 'Cordie', 'Petrelli')
# Вывод строки #72: (265, 'Pennie', 'Stoile')
# Вывод строки #73: (278, 'Sydney', 'Georger')
# Вывод строки #74: (280, 'Welch', 'MacAllaster')
# Вывод строки #75: (281, 'Jeanette', 'Sizzey')
# Вывод строки #76: (282, 'Lauren', 'Curcher')
# Вывод строки #77: (284, 'Seth', 'Moorman')
# Вывод строки #78: (286, 'Kiley', 'Canaan')
# Вывод строки #79: (292, 'Gelya', 'Gerant')
# Вывод строки #80: (296, 'Marshal', 'Rathbone')
# Вывод строки #81: (307, 'Ruben', 'Handlin')
# Вывод строки #82: (312, 'Garek', 'Prattin')
# Вывод строки #83: (314, 'Catie', 'Advani')
# Вывод строки #84: (325, 'Anthia', 'Ghilardini')
# Вывод строки #85: (329, 'Garvy', 'Berthel')
# Вывод строки #86: (330, 'Port', 'Pancost')
# Вывод строки #87: (333, 'Debbi', 'Doohey')
# Вывод строки #88: (334, 'Fredi', 'Iannuzzelli')
# Вывод строки #89: (337, 'Shaylah', 'Urquhart')
# Вывод строки #90: (344, 'Carlene', 'Eyckelbeck')
# Вывод строки #91: (345, 'Tish', 'Oleksiak')
# Вывод строки #92: (359, 'Dulcine', 'Gauson')
# Вывод строки #93: (362, 'Jamima', 'Pirolini')
# Вывод строки #94: (370, 'Trstram', 'Bondesen')
# Вывод строки #95: (372, 'Moina', 'Thumim')
# Вывод строки #96: (373, 'Eva', 'Colenutt')
# Вывод строки #97: (379, 'Bert', 'Ainslie')
# Вывод строки #98: (389, 'Dorene', 'Scrivner')
# Вывод строки #99: (394, 'Roanne', 'Cowthard')
# Вывод строки #100: (395, 'Penn', 'Burkinshaw')
# Вывод строки #101: (396, 'Peria', 'Iscowitz')
# Вывод строки #102: (397, 'Nerissa', 'Foote')
# Вывод строки #103: (399, 'Nickie', 'Neissen')
# Вывод строки #104: (404, 'Sinclair', 'Sustins')
# Вывод строки #105: (405, 'Vivien', 'Urion')
# Вывод строки #106: (407, 'Chryste', 'Acum')
# Вывод строки #107: (413, 'Simone', 'Denys')
# Вывод строки #108: (415, 'Conchita', 'Jeans')
# Вывод строки #109: (1899, 'Lambert', 'Vardey')
# Вывод строки #110: (428, 'Freida', 'Everil')
# Вывод строки #111: (429, 'Berny', 'Bold')
# Вывод строки #112: (430, 'Janice', 'Himsworth')
# Вывод строки #113: (431, 'Gale', 'Done')
# Вывод строки #114: (432, 'Amby', 'Pentin')
# Вывод строки #115: (437, 'Sayres', 'Duthie')
# Вывод строки #116: (438, 'Ebenezer', 'Bottelstone')
# Вывод строки #117: (443, 'Lauree', 'Leason')
# Вывод строки #118: (446, 'Marilee', 'Oosthout de Vree')
# Вывод строки #119: (449, 'Shana', 'Fortesquieu')
# Вывод строки #120: (456, 'Randolph', 'Redihalgh')
# Вывод строки #121: (457, 'Querida', 'Danilchev')
# Вывод строки #122: (458, 'Osborn', 'Pentony')
# Вывод строки #123: (460, 'Illa', '')
# Вывод строки #124: (462, 'Melany', 'Thorrington')
# Вывод строки #125: (465, 'Alina', 'Wilsey')
# Вывод строки #126: (466, 'Jarad', 'Bauser')
# Вывод строки #127: (468, 'Valeria', 'Ladyman')
# Вывод строки #128: (469, 'Levi', 'Cartmell')
# Вывод строки #129: (477, 'Cheri', 'Hazeman')
# Вывод строки #130: (478, 'Darcey', 'Harberer')
# Вывод строки #131: (486, 'Prudi', 'Edon')
# Вывод строки #132: (491, 'Andrea', 'Funcheon')
# Вывод строки #133: (496, 'Korry', 'Cosgrove')
# Вывод строки #134: (498, 'Emmalee', 'Sketcher')
# Вывод строки #135: (500, 'Lazar', 'Crathern')
# Вывод строки #136: (503, 'Burr', 'Gerb')
# Вывод строки #137: (504, 'Vinny', 'Hegley')
# Вывод строки #138: (505, 'Wylma', 'Elsy')
# Вывод строки #139: (509, 'Tobe', 'Vamplew')
# Вывод строки #140: (520, 'Jazmin', 'Neumann')
# Вывод строки #141: (522, 'Lynnelle', 'Comettoi')
# Вывод строки #142: (523, 'Elberta', 'Tixall')
# Вывод строки #143: (529, 'Sandor', 'Tumber')
# Вывод строки #144: (541, 'Annissa', 'Balmforth')
# Вывод строки #145: (543, 'Mikey', 'Rizzetti')
# Вывод строки #146: (544, 'Giacomo', 'Johanning')
# Вывод строки #147: (552, 'Hilly', 'Kleinmann')
# Вывод строки #148: (553, 'Charlean', 'Fantone')
# Вывод строки #149: (557, 'Cassie', 'Morley')
# Вывод строки #150: (559, 'Erma', 'Vyel')
# Вывод строки #151: (566, 'Datha', 'McPheat')
# Вывод строки #152: (572, 'Clementius', 'Everington')
# Вывод строки #153: (575, 'Etan', 'Poyle')
# Вывод строки #154: (578, 'Charyl', 'Haimes')
# Вывод строки #155: (584, 'Fiona', 'Clines')
# Вывод строки #156: (601, 'Ken', 'Renfree')
# Вывод строки #157: (602, 'Lebbie', 'Bruck')
# Вывод строки #158: (608, 'Alisun', 'Heinecke')
# Вывод строки #159: (618, 'Lucho', 'Mitie')
# Вывод строки #160: (625, 'Abra', 'Probets')
# Вывод строки #161: (630, "D'arcy", 'Rowden')
# Вывод строки #162: (633, 'Alair', 'Hopkins')
# Вывод строки #163: (640, 'Galvin', "O'Keenan")
# Вывод строки #164: (652, 'Edee', 'Stoker')
# Вывод строки #165: (653, 'Maxy', 'Hurles')
# Вывод строки #166: (655, 'Stuart', 'Gebhardt')
# Вывод строки #167: (656, 'Marty', 'Lebreton')
# Вывод строки #168: (658, 'Donn', 'Bonnell')
# Вывод строки #169: (659, 'Natalee', 'Stringman')
# Вывод строки #170: (663, 'Massimo', 'Seymour')
# Вывод строки #171: (666, 'Anselma', 'Ricardon')
# Вывод строки #172: (667, 'Nicoline', 'Samwayes')
# Вывод строки #173: (676, 'Curtis', '')
# Вывод строки #174: (682, 'Ole', 'Euplate')
# Вывод строки #175: (686, 'Hallie', 'Le feaver')
# Вывод строки #176: (687, 'Welby', 'Ninnotti')
# Вывод строки #177: (689, 'Hamnet', 'Berford')
# Вывод строки #178: (690, 'Lindsey', '')
# Вывод строки #179: (691, 'Carver', 'Carwardine')
# Вывод строки #180: (693, 'Bambi', 'Hebblethwaite')
# Вывод строки #181: (696, 'Arch', 'Gaitskill')
# Вывод строки #182: (698, 'Ellette', 'Fahy')
# Вывод строки #183: (699, 'Mirabella', 'Richter')
# Вывод строки #184: (706, 'Kane', 'Gaffer')
# Вывод строки #185: (710, 'Benton', 'Oakly')
# Вывод строки #186: (714, 'Burtie', 'Scintsbury')
# Вывод строки #187: (721, 'Harmonia', 'Cornock')
# Вывод строки #188: (725, 'Gage', 'Crossan')
# Вывод строки #189: (744, 'Heinrik', '')
# Вывод строки #190: (746, 'Aldo', 'Waistall')
# Вывод строки #191: (750, 'Izaak', 'Gisborne')
# Вывод строки #192: (753, 'Josy', 'St. Quentin')
# Вывод строки #193: (758, 'Teena', 'Birrel')
# Вывод строки #194: (761, 'Vaughan', 'McCromley')
# Вывод строки #195: (768, 'Alexia', 'Wolford')
# Вывод строки #196: (770, 'Zara', 'Maccaddie')
# Вывод строки #197: (771, 'Lammond', 'MacGeffen')
# Вывод строки #198: (773, 'Robbie', 'Handaside')
# Вывод строки #199: (784, 'Frederik', 'Duckett')
# Вывод строки #200: (787, 'Norma', 'Batrim')
# Вывод строки #201: (789, 'Gabrielle', 'Giraudot')
# Вывод строки #202: (792, 'Mitch', 'Rains')
# Вывод строки #203: (793, 'Kissie', 'Delong')
# Вывод строки #204: (794, 'Scott', 'Ommundsen')
# Вывод строки #205: (804, 'Henrietta', 'Seater')
# Вывод строки #206: (808, 'Nigel', 'Phippard')
# Вывод строки #207: (819, 'Temp', 'Thebeau')
# Вывод строки #208: (824, 'Fleurette', 'Whardley')
# Вывод строки #209: (825, 'Willis', 'Whyler')
# Вывод строки #210: (829, 'Byran', 'Goodfield')
# Вывод строки #211: (833, 'Wadsworth', 'Hubane')
# Вывод строки #212: (840, 'Chas', 'Carabet')
# Вывод строки #213: (841, 'Hanan', 'McGreay')
# Вывод строки #214: (843, 'Salomone', 'Sleford')
# Вывод строки #215: (851, 'Cammi', 'Tesmond')
# Вывод строки #216: (852, 'Andie', 'Bonney')
# Вывод строки #217: (855, 'Bennie', 'Llywarch')
# Вывод строки #218: (858, 'Barby', 'Charlwood')
# Вывод строки #219: (859, 'Devinne', 'Tommeo')
# Вывод строки #220: (860, 'Ida', '')
# Вывод строки #221: (862, 'Worden', 'Fossitt')
# Вывод строки #222: (864, 'Regen', 'Nares')
# Вывод строки #223: (866, 'Stanislaus', 'Gottelier')
# Вывод строки #224: (869, 'Addia', 'Abels')
# Вывод строки #225: (873, 'Worthington', 'Penwarden')
# Вывод строки #226: (880, 'Neely', 'Lundon')
# Вывод строки #227: (889, 'Ezequiel', 'Coggeshall')
# Вывод строки #228: (891, 'Talbot', 'Andrioni')
# Вывод строки #229: (894, 'Catie', 'Kibbey')
# Вывод строки #230: (899, 'Teodora', 'Lawling')
# Вывод строки #231: (904, 'Kariotta', 'Ludman')
# Вывод строки #232: (906, 'Cammy', 'Marcroft')
# Вывод строки #233: (907, 'Eamon', 'McWhin')
# Вывод строки #234: (908, 'Carry', 'Tomlett')
# Вывод строки #235: (909, 'Suzette', 'Surgison')
# Вывод строки #236: (914, 'Marc', 'Egleton')
# Вывод строки #237: (928, 'Porty', 'Clemmitt')
# Вывод строки #238: (931, 'Katrina', 'Sappson')
# Вывод строки #239: (941, 'Tye', 'Doohan')
# Вывод строки #240: (943, 'Holly', 'Gamett')
# Вывод строки #241: (945, 'Hebert', 'Bernocchi')
# Вывод строки #242: (952, 'Marina', 'Andresen')
# Вывод строки #243: (957, 'Jamima', 'Gannan')
# Вывод строки #244: (959, 'Katharina', 'Jennins')
# Вывод строки #245: (962, 'Granger', 'Tuftin')
# Вывод строки #246: (963, 'Valery', 'Haresign')
# Вывод строки #247: (965, 'Meggie', 'Whitchurch')
# Вывод строки #248: (966, 'Krystyna', 'Linning')
# Вывод строки #249: (967, 'April', 'Causon')
# Вывод строки #250: (968, 'Wayne', 'Woodfin')
# Вывод строки #251: (969, 'Jo', 'Mallinar')
# Вывод строки #252: (970, 'Kellyann', 'Hawton')
# Вывод строки #253: (977, 'Olga', 'Dyke')
# Вывод строки #254: (982, 'Tibold', 'Bonwell')
# Вывод строки #255: (987, 'Lars', 'Keher')
# Вывод строки #256: (994, 'Rhetta', 'Kupker')
# Вывод строки #257: (998, 'Petunia', 'Dufton')
# Вывод строки #258: (1005, 'Kalila', 'Birtwistle')
# Вывод строки #259: (1006, 'Norbert', 'Gotcher')
# Вывод строки #260: (1009, 'Nolie', 'Orring')
# Вывод строки #261: (1011, 'Cymbre', 'Janos')
# Вывод строки #262: (1012, 'Anna-diane', 'Preddle')
# Вывод строки #263: (1022, 'Suzann', 'Wilks')
# Вывод строки #264: (1023, 'Iseabal', 'Fullbrook')
# Вывод строки #265: (1024, 'Rhodia', "D'Onise")
# Вывод строки #266: (1033, 'Jacob', 'Claringbold')
# Вывод строки #267: (1034, 'Denney', 'Cretney')
# Вывод строки #268: (1035, 'Kara-lynn', 'Doddridge')
# Вывод строки #269: (1039, 'Nona', 'Diamant')
# Вывод строки #270: (1042, 'Isacco', 'Woodwind')
# Вывод строки #271: (1051, 'Xylia', 'Lange')
# Вывод строки #272: (1058, 'Gretel', 'Gionettitti')
# Вывод строки #273: (1059, 'Chantal', 'Plante')
# Вывод строки #274: (1060, 'Vanda', 'Boadby')
# Вывод строки #275: (1063, 'Terrence', 'Geck')
# Вывод строки #276: (1064, 'Thornie', 'Andrusov')
# Вывод строки #277: (1072, 'Curt', 'Petrello')
# Вывод строки #278: (1073, 'Elbertina', 'Donne')
# Вывод строки #279: (1074, 'Griswold', 'Juett')
# Вывод строки #280: (1088, 'Andy', 'Polgreen')
# Вывод строки #281: (1099, 'Jarrett', 'Maffia')
# Вывод строки #282: (1103, 'Glynnis', 'Sailor')
# Вывод строки #283: (1111, 'Zach', 'Maynard')
# Вывод строки #284: (1115, 'Merola', 'Stutard')
# Вывод строки #285: (1124, 'Eben', 'Threader')
# Вывод строки #286: (1132, 'Coriss', 'Darkott')
# Вывод строки #287: (1141, 'Shannah', 'Gritsaev')
# Вывод строки #288: (1144, 'Damon', 'Phelip')
# Вывод строки #289: (1147, 'Tate', 'Studholme')
# Вывод строки #290: (1149, 'Ki', 'Odo')
# Вывод строки #291: (1151, 'Brena', 'Amburgy')
# Вывод строки #292: (1157, 'Saunder', 'Camerati')
# Вывод строки #293: (1163, 'Manolo', 'Dwire')
# Вывод строки #294: (1171, 'Ilise', 'Solloway')
# Вывод строки #295: (1176, 'Celia', 'Dockerty')
# Вывод строки #296: (1177, 'Bobbette', 'Pozzi')
# Вывод строки #297: (1179, 'Kerry', 'Pashenkov')
# Вывод строки #298: (1186, 'Brantley', 'Cecchi')
# Вывод строки #299: (1188, 'Sally', 'Cominoli')
# Вывод строки #300: (1189, 'Mart', 'Bazoche')
# Вывод строки #301: (1190, 'Sib', 'Gilby')
# Вывод строки #302: (1197, 'Isobel', 'Lampett')
# Вывод строки #303: (1199, 'Ludovico', 'Bertot')
# Вывод строки #304: (1204, 'Trudy', 'Huffy')
# Вывод строки #305: (1209, 'Jacky', 'Jerosch')
# Вывод строки #306: (1211, 'Gunar', 'Petasch')
# Вывод строки #307: (1216, 'Frank', 'Vallerine')
# Вывод строки #308: (1221, 'Byrom', 'Draisey')
# Вывод строки #309: (1227, 'Carlina', 'Pencot')
# Вывод строки #310: (1229, 'Sebastian', 'Trass')
# Вывод строки #311: (1236, 'Bryanty', 'Megarrell')
# Вывод строки #312: (1238, 'Steward', 'Beedham')
# Вывод строки #313: (1241, 'Lolly', 'Junkison')
# Вывод строки #314: (1242, 'Bartholomeo', 'Meeke')
# Вывод строки #315: (1248, 'Genia', 'Bartel')
# Вывод строки #316: (1257, 'Prentiss', 'MacVicar')
# Вывод строки #317: (1262, 'Aindrea', 'MacConchie')
# Вывод строки #318: (1267, 'Leopold', 'Dainton')
# Вывод строки #319: (1268, 'Baudoin', 'McCartney')
# Вывод строки #320: (1269, 'Ravid', 'Kilgallon')
# Вывод строки #321: (1273, 'Hieronymus', 'Whinray')
# Вывод строки #322: (1280, 'Horacio', 'Peyntue')
# Вывод строки #323: (1281, 'Leighton', 'Zisneros')
# Вывод строки #324: (1282, 'Garald', 'Pidler')
# Вывод строки #325: (1286, 'Mina', 'Clawley')
# Вывод строки #326: (1288, 'Abra', 'Cuardall')
# Вывод строки #327: (1290, 'Vassily', 'Ramalho')
# Вывод строки #328: (1296, 'Essy', 'Vondrak')
# Вывод строки #329: (1300, 'Sisely', 'Strelitzer')
# Вывод строки #330: (1302, 'Ericka', 'Eggers')
# Вывод строки #331: (1305, 'Averil', 'Gentiry')
# Вывод строки #332: (1306, 'Doyle', 'Oleksinski')
# Вывод строки #333: (1307, 'Emlyn', 'Musgrave')
# Вывод строки #334: (1308, 'Andrey', 'Conre')
# Вывод строки #335: (1310, 'Keane', 'Leebeter')
# Вывод строки #336: (1316, 'Steven', 'Castellaccio')
# Вывод строки #337: (1320, 'Fae', '')
# Вывод строки #338: (1323, 'Kristofor', 'Mockes')
# Вывод строки #339: (1325, 'Ty', 'Belliard')
# Вывод строки #340: (1326, 'Goddard', 'Tinn')
# Вывод строки #341: (1342, 'Barnett', 'Morville')
# Вывод строки #342: (1362, 'Giuditta', 'Dearlove')
# Вывод строки #343: (1378, 'Ellie', 'Prester')
# Вывод строки #344: (1381, 'Ellary', 'Ramsey')
# Вывод строки #345: (1382, 'Lucio', 'Reame')
# Вывод строки #346: (1390, 'Christyna', 'Feldberg')
# Вывод строки #347: (1395, 'Jandy', 'Pennazzi')
# Вывод строки #348: (1400, 'Rikki', 'Eytel')
# Вывод строки #349: (1405, 'Kylie', 'Spriggin')
# Вывод строки #350: (1406, 'Georges', 'Tilne')
# Вывод строки #351: (1410, 'Althea', 'Macvey')
# Вывод строки #352: (1415, 'Merilyn', 'Dikle')
# Вывод строки #353: (1416, 'Fraze', 'Face')
# Вывод строки #354: (1417, 'Micki', 'Russel')
# Вывод строки #355: (1418, 'Valaria', 'Hugh')
# Вывод строки #356: (1422, 'Georgy', 'Rickwood')
# Вывод строки #357: (1424, 'Allin', 'Arbuckel')
# Вывод строки #358: (1425, 'Chrisy', 'Sivess')
# Вывод строки #359: (1431, 'Derek', 'Malafe')
# Вывод строки #360: (1432, 'Hiram', 'Kittiman')
# Вывод строки #361: (1435, 'Derek', 'Podmore')
# Вывод строки #362: (1440, 'Consuela', "O'Logan")
# Вывод строки #363: (1443, 'Angela', 'Mowles')
# Вывод строки #364: (1457, 'Leonore', 'Slixby')
# Вывод строки #365: (1460, 'Morley', 'Shutt')
# Вывод строки #366: (1463, 'Willie', 'Landsberg')
# Вывод строки #367: (1464, 'Mac', 'Leguay')
# Вывод строки #368: (1466, 'Cyndia', 'Gull')
# Вывод строки #369: (1469, 'Shermy', '')
# Вывод строки #370: (1470, 'Albie', 'Pach')
# Вывод строки #371: (1475, 'Aristotle', 'Jess')
# Вывод строки #372: (1476, 'Vaughn', 'Browse')
# Вывод строки #373: (1480, 'Bird', 'Diess')
# Вывод строки #374: (1487, 'Kaela', 'Soppett')
# Вывод строки #375: (1495, 'Charmion', 'Dobsons')
# Вывод строки #376: (1498, 'Janot', 'McGougan')
# Вывод строки #377: (1502, 'Margalit', 'Handrick')
# Вывод строки #378: (1504, 'Coop', 'Corneck')
# Вывод строки #379: (1507, 'Holmes', 'Benkin')
# Вывод строки #380: (1508, 'Orv', 'Milland')
# Вывод строки #381: (1513, 'Wendel', 'Cator')
# Вывод строки #382: (1519, 'Marwin', 'Jeyness')
# Вывод строки #383: (1521, 'Pernell', 'Duffett')
# Вывод строки #384: (1529, 'Tansy', 'Beltzner')
# Вывод строки #385: (1533, 'Sonia', 'Rous')
# Вывод строки #386: (1535, 'Emanuel', 'Baukham')
# Вывод строки #387: (1536, 'Tiffany', 'Fanshaw')
# Вывод строки #388: (1538, 'Ahmed', 'Edmondson')
# Вывод строки #389: (1544, 'Keane', 'Moneypenny')
# Вывод строки #390: (1549, 'Vikki', 'Tett')
# Вывод строки #391: (1559, 'Hilton', 'Gladwell')
# Вывод строки #392: (1562, 'Elset', 'Biasio')
# Вывод строки #393: (1565, 'Jay', 'Janiszewski')
# Вывод строки #394: (1572, 'Tam', 'Jahner')
# Вывод строки #395: (1574, 'Werner', 'Wall')
# Вывод строки #396: (1578, 'Andreas', 'Bazely')
# Вывод строки #397: (1579, 'Madelaine', 'Siegertsz')
# Вывод строки #398: (1587, 'Kevan', 'Laminman')
# Вывод строки #399: (1588, 'Dukey', 'McCrie')
# Вывод строки #400: (1595, 'Kora', 'Paoli')
# Вывод строки #401: (1596, 'Vinnie', 'Sails')
# Вывод строки #402: (1603, 'Osgood', 'Emerine')
# Вывод строки #403: (1606, 'Shayne', 'Ellesworthe')
# Вывод строки #404: (1610, 'Valaree', 'Chisolm')
# Вывод строки #405: (1611, 'Terencio', '')
# Вывод строки #406: (1612, 'Wendel', 'Headland')
# Вывод строки #407: (1616, 'Shamus', 'Attenbrough')
# Вывод строки #408: (1620, 'Jerrold', 'Bernetti')
# Вывод строки #409: (1623, 'Katy', 'Taffee')
# Вывод строки #410: (1632, 'Orbadiah', 'Kennicott')
# Вывод строки #411: (1633, 'Ashia', 'Muzzi')
# Вывод строки #412: (1636, 'Karly', 'Ackenhead')
# Вывод строки #413: (1640, 'Erie', 'Worswick')
# Вывод строки #414: (1642, 'Nollie', 'Matteoli')
# Вывод строки #415: (1645, 'Dal', 'Colquhoun')
# Вывод строки #416: (1647, 'Ivory', 'Roscam')
# Вывод строки #417: (1652, 'Ulrikaumeko', 'Heffernon')
# Вывод строки #418: (1654, 'Melli', 'Sperwell')
# Вывод строки #419: (1655, 'Prinz', 'Codman')
# Вывод строки #420: (1659, 'Olva', 'Sheehy')
# Вывод строки #421: (1663, 'Analiese', 'Grimsditch')
# Вывод строки #422: (1664, 'Karlis', 'Alner')
# Вывод строки #423: (1669, 'Jabez', 'Glasspoole')
# Вывод строки #424: (1672, 'Sharla', 'Creebo')
# Вывод строки #425: (1673, 'Suzie', 'Dahle')
# Вывод строки #426: (1675, 'Luke', 'Wombwell')
# Вывод строки #427: (1677, 'Petrina', 'Pollins')
# Вывод строки #428: (1678, 'Dale', 'Hursey')
# Вывод строки #429: (1681, 'Rupert', 'Gilstoun')
# Вывод строки #430: (1682, 'Gerladina', 'Cuddon')
# Вывод строки #431: (1687, 'Chance', 'Maben')
# Вывод строки #432: (1690, 'Torey', 'Kensall')
# Вывод строки #433: (1691, 'Tomlin', '')
# Вывод строки #434: (1695, 'Blanch', 'Leyshon')
# Вывод строки #435: (1698, 'Christabella', 'Eldredge')
# Вывод строки #436: (1700, 'Rana', 'Streets')
# Вывод строки #437: (1706, 'Slade', 'Semark')
# Вывод строки #438: (1711, 'Marie-jeanne', 'Mattson')
# Вывод строки #439: (1712, 'Chad', '')
# Вывод строки #440: (1713, 'Jennica', 'Jeeks')
# Вывод строки #441: (1714, 'Esma', 'Rycroft')
# Вывод строки #442: (1718, 'Eada', 'Coaster')
# Вывод строки #443: (1724, 'Davita', 'Pristnor')
# Вывод строки #444: (1725, 'Corena', 'Postlewhite')
# Вывод строки #445: (1731, 'Aigneis', 'MacKall')
# Вывод строки #446: (1737, 'Benny', 'Jammet')
# Вывод строки #447: (1738, 'Frankie', 'Seydlitz')
# Вывод строки #448: (1743, 'Pall', 'Creek')
# Вывод строки #449: (1753, 'Kerry', 'Ford')
# Вывод строки #450: (1763, 'Suzie', 'Ornillos')
# Вывод строки #451: (1767, 'Cicely', 'Millier')
# Вывод строки #452: (1772, 'Michael', 'Foulis')
# Вывод строки #453: (1782, 'Ewen', 'Emes')
# Вывод строки #454: (1786, 'Lonee', 'Gorce')
# Вывод строки #455: (1787, 'Tull', 'Godehard.sf')
# Вывод строки #456: (1788, 'Anna-diana', 'Kurten')
# Вывод строки #457: (1791, 'Ninon', 'Van Der Hoog')
# Вывод строки #458: (1796, 'Cayla', 'Marcus')
# Вывод строки #459: (1798, 'Eunice', 'Risom')
# Вывод строки #460: (1807, 'Pollyanna', 'Serjeantson')
# Вывод строки #461: (1821, 'Fields', 'Bayne')
# Вывод строки #462: (1824, 'Robbie', 'Yakubovics')
# Вывод строки #463: (1826, 'Jareb', 'Langcaster')
# Вывод строки #464: (1827, 'Stormie', 'Smyth')
# Вывод строки #465: (1833, 'Klemens', 'Eite')
# Вывод строки #466: (1834, 'Otes', 'Gottelier')
# Вывод строки #467: (1835, 'Rodrigo', 'Felce')
# Вывод строки #468: (1838, 'Jobina', 'Dudenie')
# Вывод строки #469: (1839, 'Faythe', 'Rance')
# Вывод строки #470: (1840, 'Sherman', 'Gullen')
# Вывод строки #471: (1854, 'Mandie', 'Jeger')
# Вывод строки #472: (1857, 'Purcell', 'Chinnery')
# Вывод строки #473: (1858, 'Gabriella', '')
# Вывод строки #474: (1859, 'Melamie', 'Hardman')
# Вывод строки #475: (1862, 'Daron', 'Umpleby')
# Вывод строки #476: (1869, 'Neda', 'Longfellow')
# Вывод строки #477: (1871, 'Shayna', 'McQuin')
# Вывод строки #478: (1873, 'Raul', 'Cabrer')
# Вывод строки #479: (1874, 'Nickolai', 'McChesney')
# Вывод строки #480: (1875, 'Amory', 'Bohler')
# Вывод строки #481: (1877, 'Radcliffe', 'Bartolomeoni')
# Вывод строки #482: (1881, 'Gherardo', 'Lahy')
# Вывод строки #483: (1885, 'Jerome', 'Sheavills')
# Вывод строки #484: (1887, 'Kynthia', 'Purcer')
# Вывод строки #485: (1892, 'Allyson', 'Pinsent')
# Вывод строки #486: (1894, 'Patten', 'Laytham')
# Вывод строки #487: (1898, 'Katalin', 'Mantz')
# Вывод строки #488: (1900, 'Noland', 'Larder')
# Вывод строки #489: (1903, 'Tucky', 'Pizzie')
# Вывод строки #490: (1904, 'Nert', 'Muglestone')
# Вывод строки #491: (1908, 'Jaquelyn', 'Workman')
# Вывод строки #492: (1909, 'Drucill', 'Laurand')
# Вывод строки #493: (1910, 'Yovonnda', 'Warrior')
# Вывод строки #494: (1916, 'Redd', "O'Crowley")
# Вывод строки #495: (1917, 'Raquela', 'Schimpke')
# Вывод строки #496: (1922, 'Ailene', 'Tomkies')
# Вывод строки #497: (1926, 'Stefano', 'Menhenitt')
# Вывод строки #498: (1927, 'Masha', 'Bibbie')
# Вывод строки #499: (1928, 'Sully', 'Dorling')
# Вывод строки #500: (1932, 'Sybila', 'Enefer')
# Вывод строки #501: (1934, 'Bryant', 'Tordiffe')
# Вывод строки #502: (1940, 'Gabriellia', 'Coulter')
# Вывод строки #503: (1943, 'Armstrong', 'Style')
# Вывод строки #504: (1944, 'Gregory', 'Balchin')
# Вывод строки #505: (1945, 'Griffin', 'Gisbourn')
# Вывод строки #506: (1947, 'Gretta', 'Patrone')
# Вывод строки #507: (1950, 'Berne', 'Fulkes')
# Вывод строки #508: (1956, 'Omero', 'Murra')
# Вывод строки #509: (1964, 'Cara', 'Campbell-Dunlop')
# Вывод строки #510: (1967, 'Nomi', '')
# Вывод строки #511: (1980, 'Kenneth', 'Viall')
# Вывод строки #512: (1982, 'Julee', 'Hallewell')
# Вывод строки #513: (1983, 'Kimberlee', 'Soonhouse')
# Вывод строки #514: (1989, 'Emalee', 'Guitel')
# Вывод строки #515: (1993, 'Agustin', 'Isworth')
# Вывод строки #516: (2003, 'Lilli', 'Hargey')
# Вывод строки #517: (2004, 'Brandy', 'Showering')
# Вывод строки #518: (2006, 'Hyacinthia', 'Tuley')
# Вывод строки #519: (2009, 'Neilla', 'Castrillo')
# Вывод строки #520: (2010, 'Duff', 'Guyer')
# Вывод строки #521: (2011, 'Guthrie', 'MacAne')
# Вывод строки #522: (2013, 'Marge', 'Girault')
# Вывод строки #523: (2016, 'Laraine', 'Merioth')
# Вывод строки #524: (2017, 'Ezri', 'Sadry')
# Вывод строки #525: (2020, 'Portia', 'Proudlock')
# Вывод строки #526: (2028, 'Cathy', 'Parmley')
# Вывод строки #527: (2039, 'Laureen', 'Blower')
# Вывод строки #528: (2040, 'Gal', 'Scardafield')
# Вывод строки #529: (2047, 'Kirsten', 'Slegg')
# Вывод строки #530: (2053, 'Horatius', 'Dufton')
# Вывод строки #531: (2057, 'Elianora', 'Sally')
# Вывод строки #532: (2066, 'Skipp', 'McLarens')
# Вывод строки #533: (2073, 'Linea', '')
# Вывод строки #534: (2082, 'Sybyl', 'Beekman')
# Вывод строки #535: (2096, 'Torrie', 'Smartman')
# Вывод строки #536: (2099, 'Mikel', 'McKechnie')
# Вывод строки #537: (2105, 'Terrance', 'Goligher')
# Вывод строки #538: (2106, 'Antons', 'Ley')
# Вывод строки #539: (2107, 'Dre', 'Ferrillo')
# Вывод строки #540: (2109, 'Grazia', 'Vinson')
# Вывод строки #541: (2111, 'Ellis', 'Vokes')
# Вывод строки #542: (2116, 'Wyndham', 'Ecob')
# Вывод строки #543: (2122, 'Osborne', 'Nawton')
# Вывод строки #544: (2128, 'Gregorius', 'Cockram')
# Вывод строки #545: (2130, 'Evangelina', 'Coxhell')
# Вывод строки #546: (2132, 'Davina', 'Dougary')
# Вывод строки #547: (2136, 'Heather', 'Golsworthy')
# Вывод строки #548: (2139, 'Carolina', 'Brands')
# Вывод строки #549: (2141, 'Georgie', 'Bruggen')
# Вывод строки #550: (2143, 'Napoleon', 'Terron')
# Вывод строки #551: (2145, 'Adrea', 'Quittonden')
# Вывод строки #552: (2147, 'Franzen', 'Kielty')
# Вывод строки #553: (2150, 'Huntlee', 'Pashba')
# Вывод строки #554: (2159, 'Godfrey', 'Bottini')
# Вывод строки #555: (2162, 'Andrew', 'Blunt')
# Вывод строки #556: (2172, 'Emmery', 'Angrock')
# Вывод строки #557: (2176, 'Josie', 'Gallemore')
# Вывод строки #558: (2180, 'Urbanus', 'Trevaskus')
# Вывод строки #559: (2182, 'Symon', 'Minchin')
# Вывод строки #560: (2194, 'Johnette', "O'Fergus")
# Вывод строки #561: (2195, 'Nevsa', 'Taill')
# Вывод строки #562: (2196, 'Skylar', 'Brise')
# Вывод строки #563: (2198, 'Marijn', 'Arnoll')
# Вывод строки #564: (2199, 'Leigha', 'Ranger')
# Вывод строки #565: (2200, 'Teodoor', 'Lovelace')
# Вывод строки #566: (2201, 'Trisha', 'Basset')
# Вывод строки #567: (2202, 'Diannne', 'Neissen')
# Вывод строки #568: (2203, 'Ganny', 'Alessandrelli')
# Вывод строки #569: (2209, 'Rriocard', 'Gavan')
# Вывод строки #570: (2212, 'Adrianne', 'Raoux')
# Вывод строки #571: (2213, 'Jesse', 'Leyshon')
# Вывод строки #572: (2214, 'Farlay', 'Plevey')
# Вывод строки #573: (2216, 'Clarinda', 'Woffinden')
# Вывод строки #574: (2219, 'Ansel', 'Napier')
# Вывод строки #575: (2224, 'Sydel', 'Seccombe')
# Вывод строки #576: (2227, 'Duff', 'Kemble')
# Вывод строки #577: (2229, 'Linette', 'Gotmann')
# Вывод строки #578: (2236, 'Arin', 'Crickmoor')
# Вывод строки #579: (2239, 'Jocelyne', 'Pasquale')
# Вывод строки #580: (2240, 'Niall', 'Hallifax')
# Вывод строки #581: (2243, 'Lena', 'Cronshaw')
# Вывод строки #582: (2247, 'Gweneth', 'Wilkins')
# Вывод строки #583: (2253, 'Gracie', 'Kubacki')
# Вывод строки #584: (2255, 'Iorgo', 'Krol')
# Вывод строки #585: (2275, 'Ursulina', 'Carter')
# Вывод строки #586: (2277, 'Gillie', 'Ruben')
# Вывод строки #587: (2278, 'Gerri', 'Heliet')
# Вывод строки #588: (2281, 'Valaria', 'Abrehart')
# Вывод строки #589: (2282, 'Dominic', 'Gregoletti')
# Вывод строки #590: (2289, 'Kissie', 'Steanson')
# Вывод строки #591: (2291, 'Guido', 'Meynell')
# Вывод строки #592: (2297, 'Pauletta', 'Taffee')
# Вывод строки #593: (2299, 'Mahmoud', 'Dagworthy')
# Вывод строки #594: (2305, 'Aeriell', 'Greeding')
# Вывод строки #595: (2306, 'Hilary', 'Tregunna')
# Вывод строки #596: (2307, 'Corina', 'Shadwick')
# Вывод строки #597: (2310, 'Jed', 'Humpherston')
# Вывод строки #598: (2314, 'Ravid', 'Lapenna')
# Вывод строки #599: (2316, 'Vernen', 'Bourgaize')
# Вывод строки #600: (2325, 'Emmett', 'Whatsize')
# Вывод строки #601: (2332, 'Jeff', 'Goodere')
# Вывод строки #602: (2339, 'Damien', 'Haddeston')
# Вывод строки #603: (2343, 'Wilhelm', 'Corteis')
# Вывод строки #604: (2345, 'Arden', 'Godard')
# Вывод строки #605: (2351, 'Felicity', 'Beirne')
# Вывод строки #606: (2353, 'Lyn', 'Luquet')
# Вывод строки #607: (2358, 'Ave', 'Peatt')
# Вывод строки #608: (2359, 'Merlina', 'Bream')
# Вывод строки #609: (2360, 'Karleen', 'McGenn')
# Вывод строки #610: (2361, 'Jeannette', 'Cerman')
# Вывод строки #611: (2362, 'Herbie', 'Machans')
# Вывод строки #612: (2371, 'Rory', 'Lokier')
# Вывод строки #613: (2373, 'Cordy', 'Readshall')
# Вывод строки #614: (2376, 'Eada', 'Narbett')
# Вывод строки #615: (2379, 'Trixie', 'Piscopiello')
# Вывод строки #616: (2381, 'Dulsea', 'Pladen')
# Вывод строки #617: (2384, 'Garey', 'Letrange')
# Вывод строки #618: (2387, 'Roy', 'Jone')
# Вывод строки #619: (2393, 'Dorian', 'Colledge')
# Вывод строки #620: (2396, 'Elmira', 'Wildblood')
# Вывод строки #621: (2397, 'Cassius', 'Birchenough')
# Вывод строки #622: (2398, 'Mirelle', '')
# Вывод строки #623: (2399, 'Devonne', 'McPolin')
# Вывод строки #624: (2406, 'Randal', 'Messager')
# Вывод строки #625: (2407, 'Merrily', '')
# Вывод строки #626: (2413, 'Abbey', 'Murrow')
# Вывод строки #627: (2421, 'Marilee', 'Garbott')
# Вывод строки #628: (2424, 'Loren', 'Batkin')
# Вывод строки #629: (2427, 'Myrta', 'Whibley')
# Вывод строки #630: (2432, 'Ebba', 'Melhuish')
# Вывод строки #631: (2433, 'Burty', 'Strutz')
# Вывод строки #632: (2441, 'Loutitia', 'Pinkie')
# Вывод строки #633: (2442, 'Odie', 'Enrrico')
# Вывод строки #634: (2447, 'Richard', 'Poor')
# Вывод строки #635: (2450, 'Jayson', 'Breheny')
# Вывод строки #636: (2451, 'Upton', 'Orford')
# Вывод строки #637: (2457, 'Benito', 'Vearnals')
# Вывод строки #638: (2458, 'Leilah', 'Liddel')
# Вывод строки #639: (2460, 'Mick', 'Boutellier')
# Вывод строки #640: (2467, 'Ynez', 'Fawloe')
# Вывод строки #641: (2472, 'Mathias', 'Element')
# Вывод строки #642: (2474, 'Chrysa', 'Burrett')
# Вывод строки #643: (2477, 'Barney', 'Tilling')
# Вывод строки #644: (2478, 'Andreas', 'Lamke')
# Вывод строки #645: (2480, 'Adey', 'Shevlin')
# Вывод строки #646: (2487, 'Elton', 'Piggford')
# Вывод строки #647: (2500, 'Micky', 'Livings')
# Вывод строки #648: (2503, 'Devlin', 'Laneham')
# Вывод строки #649: (2507, 'Alysa', 'Galilee')
# Вывод строки #650: (2512, 'Franzen', 'Halliday')
# Вывод строки #651: (2514, 'Vincenty', 'Sayer')
# Вывод строки #652: (2515, 'Manya', '')
# Вывод строки #653: (2520, 'Gabie', 'Skett')
# Вывод строки #654: (2521, 'Kellia', 'Martugin')
# Вывод строки #655: (2527, 'Arly', 'Petersen')
# Вывод строки #656: (2529, 'Ben', 'Laidler')
# Вывод строки #657: (2531, 'Brendan', 'Verbeke')
# Вывод строки #658: (2533, 'Harper', 'Ioannidis')
# Вывод строки #659: (2534, 'Estelle', 'Lithgow')
# Вывод строки #660: (2537, 'Peggi', 'Tolan')
# Вывод строки #661: (2539, 'Tracie', 'Ashdown')
# Вывод строки #662: (2541, 'Cleveland', 'Islep')
# Вывод строки #663: (2542, 'Amanda', 'Leverington')
# Вывод строки #664: (2552, 'Allard', 'Skipton')
# Вывод строки #665: (2553, 'Buddy', 'Morfell')
# Вывод строки #666: (2558, 'Imojean', 'Bosquet')
# Вывод строки #667: (2561, 'Elga', 'McWard')
# Вывод строки #668: (2565, 'Joannes', 'Harbron')
# Вывод строки #669: (2566, 'Nani', 'Brilleman')
# Вывод строки #670: (2571, 'Chariot', 'Keefe')
# Вывод строки #671: (2575, 'Hagan', 'Abrahmer')
# Вывод строки #672: (2581, 'Gwenette', 'Appleton')
# Вывод строки #673: (2590, 'Roslyn', 'Tewkesbury.')
# Вывод строки #674: (2595, 'Land', 'Bangley')
# Вывод строки #675: (2596, 'Lexis', 'Deason')
# Вывод строки #676: (2597, 'Carita', 'Kemwall')
# Вывод строки #677: (2605, 'Had', 'Gilling')
# Вывод строки #678: (2607, 'Laurent', 'Ainslee')
# Вывод строки #679: (2608, 'Fenelia', 'Dockrell')
# Вывод строки #680: (2616, 'Andee', 'Ormrod')
# Вывод строки #681: (2619, 'Lavinia', 'Niess')
# Вывод строки #682: (2625, 'Kristal', 'McRobbie')
# Вывод строки #683: (2626, 'Gerome', 'Lawrenz')
# Вывод строки #684: (2636, 'Carly', 'Struys')
# Вывод строки #685: (2645, 'Ado', 'Yaldren')
# Вывод строки #686: (2649, 'Merwyn', 'MacPhail')
# Вывод строки #687: (2650, 'Candice', 'Patriskson')
# Вывод строки #688: (2652, 'Kelbee', 'Bernat')
# Вывод строки #689: (2659, 'Konstance', 'Elgey')
# Вывод строки #690: (2660, 'Hunt', 'Scollard')
# Вывод строки #691: (2661, 'Dorrie', 'Meaden')
# Вывод строки #692: (2667, 'Randene', 'Brown')
# Вывод строки #693: (2670, 'Cam', 'MacFadyen')
# Вывод строки #694: (2681, 'Liza', 'LeEstut')
# Вывод строки #695: (2682, 'Annamarie', 'Bouzan')
# Вывод строки #696: (2683, 'Myrta', 'Rentilll')
# Вывод строки #697: (2687, 'Fabe', 'Smallbone')
# Вывод строки #698: (2690, 'Sissie', 'Giordano')
# Вывод строки #699: (2692, 'Jacklyn', 'Bromehed')
# Вывод строки #700: (2693, 'Abram', 'Phillipson')
# Вывод строки #701: (2699, 'Michal', 'Woltering')
# Вывод строки #702: (2701, 'Ileana', 'Timms')
# Вывод строки #703: (2702, 'Saraann', 'Gilliard')
# Вывод строки #704: (2703, 'Peria', 'Amis')
# Вывод строки #705: (2704, 'Orlando', 'Gniewosz')
# Вывод строки #706: (2707, 'Tabb', 'Haberjam')
# Вывод строки #707: (2712, 'Carissa', 'Hassent')
# Вывод строки #708: (2713, 'Hadlee', 'Mackro')
# Вывод строки #709: (2714, 'Emmy', 'Jenton')
# Вывод строки #710: (2718, 'Vernen', 'Hakonsen')
# Вывод строки #711: (2719, 'Alleyn', 'Clear')
# Вывод строки #712: (2727, 'Kim', 'Gabbitis')
# Вывод строки #713: (2735, 'Ricoriki', 'Burree')
# Вывод строки #714: (2736, 'Max', 'Awcock')
# Вывод строки #715: (2739, 'Alair', 'Cullingford')
# Вывод строки #716: (2740, 'Godiva', 'Bulward')
# Вывод строки #717: (2742, 'Osgood', 'Risby')
# Вывод строки #718: (2743, 'Carr', 'Muckley')
# Вывод строки #719: (2746, 'Carmelia', 'Egle of Germany')
# Вывод строки #720: (2751, 'Cordell', 'Coxhell')
# Вывод строки #721: (2752, 'Cissiee', 'Jobern')
# Вывод строки #722: (2759, 'Melodee', 'Hendrik')
# Вывод строки #723: (2766, 'Rozanna', 'Chartman')
# Вывод строки #724: (2769, 'Trevor', 'Itschakov')
# Вывод строки #725: (2770, 'Olvan', 'Loadwick')
# Вывод строки #726: (2771, 'Jamie', 'Gildersleeve')
# Вывод строки #727: (2772, 'Reynolds', 'Vreede')
# Вывод строки #728: (2779, 'Douglas', 'Wrout')
# Вывод строки #729: (2780, 'Papageno', 'Beare')
# Вывод строки #730: (2781, 'Linnea', 'Jeacop')
# Вывод строки #731: (2783, 'Antonin', 'Gleaves')
# Вывод строки #732: (2787, 'Teressa', 'Tague')
# Вывод строки #733: (2789, 'Violetta', 'Bucksey')
# Вывод строки #734: (2790, 'Shirleen', 'Shelsher')
# Вывод строки #735: (2793, 'Mead', 'Corkell')
# Вывод строки #736: (2798, 'Barclay', 'Gricks')
# Вывод строки #737: (2812, 'Molli', 'Hagergham')
# Вывод строки #738: (2814, 'Mandel', 'Hellyar')
# Вывод строки #739: (2817, 'Agata', 'Inglesent')
# Вывод строки #740: (2820, 'Tristam', 'Gutcher')
# Вывод строки #741: (2825, 'Tammara', 'Twigley')
# Вывод строки #742: (2828, 'Philippine', 'Maycey')
# Вывод строки #743: (2843, 'Lorain', 'Danforth')
# Вывод строки #744: (2849, 'Palm', 'Bartoszek')
# Вывод строки #745: (2851, 'Ulberto', 'Haking')
# Вывод строки #746: (2852, 'Clarinda', 'Noen')
# Вывод строки #747: (2853, 'Clarence', 'Flook')
# Вывод строки #748: (2871, 'Hubie', 'Keld')
# Вывод строки #749: (2872, 'Tabbi', 'Tyght')
# Вывод строки #750: (2877, 'Vaughan', 'Frank')
# Вывод строки #751: (2881, 'Ezra', 'Steffan')
# Вывод строки #752: (2887, 'Gardiner', 'Spehr')
# Вывод строки #753: (2888, 'Hamel', 'Crosser')
# Вывод строки #754: (2890, 'Nevile', 'Ecclesall')
# Вывод строки #755: (2891, 'Renae', 'Ughetti')
# Вывод строки #756: (2892, 'Paulie', 'Wolffers')
# Вывод строки #757: (2898, 'Tiertza', 'Hilldrop')
# Вывод строки #758: (2903, 'Avery', 'Adamov')
# Вывод строки #759: (2904, 'Freddi', 'Arrington')
# Вывод строки #760: (2908, 'Tiffy', 'Feenan')
# Вывод строки #761: (2913, 'Padraic', 'Bonnar')
# Вывод строки #762: (2914, 'Jessamine', 'Brazear')
# Вывод строки #763: (2916, 'Lauren', 'Adolfson')
# Вывод строки #764: (2919, 'Rustin', '')
# Вывод строки #765: (2922, 'Wallache', 'Tatlow')
# Вывод строки #766: (2923, 'Julie', 'Kennagh')
# Вывод строки #767: (2925, 'Henderson', 'Sloey')
# Вывод строки #768: (2927, 'Yard', 'Spellman')
# Вывод строки #769: (2933, 'Ralf', 'Presidey')
# Вывод строки #770: (2940, 'Wilek', 'Adolf')
# Вывод строки #771: (2952, 'Cristy', 'McQuirter')
# Вывод строки #772: (2953, 'Hector', 'Carwithan')
# Вывод строки #773: (2958, 'Regan', 'Botly')
# Вывод строки #774: (2967, 'Dud', 'Coom')
# Вывод строки #775: (2971, 'Esther', 'Caught')
# Вывод строки #776: (2981, 'Benny', 'Jadczak')
# Вывод строки #777: (2985, 'Kerby', 'Nesfield')
# Вывод строки #778: (2987, 'Riane', 'Schultes')
# Вывод строки #779: (2989, 'Mort', '')
# Вывод строки #780: (2998, 'Quintana', 'Housley')
# Вывод строки #781: (3005, 'Rafaellle', 'Tantrum')
# Вывод строки #782: (3008, 'Etta', 'Criag')
# Вывод строки #783: (3009, 'Hephzibah', 'Cliffe')
# Вывод строки #784: (3018, 'Ainsley', 'Nissle')
# Вывод строки #785: (3019, 'Alonso', 'Ceyssen')
# Вывод строки #786: (3020, 'Witty', 'McArthur')
# Вывод строки #787: (3023, 'Rikki', 'Bernet')
# Вывод строки #788: (3032, 'Renado', 'Wonfor')
# Вывод строки #789: (3036, 'Windy', 'Orehead')
# Вывод строки #790: (3037, 'Leanora', 'Isles')
# Вывод строки #791: (3042, 'Barris', 'Trayton')
# Вывод строки #792: (3044, 'Russell', 'Brittoner')
# Вывод строки #793: (3045, 'Renato', 'Mungham')
# Вывод строки #794: (3049, 'Tristam', "O'Fallone")
# Вывод строки #795: (3051, 'Edi', 'Lugton')
# Вывод строки #796: (3061, 'Evie', 'Bendtsen')
# Вывод строки #797: (3064, 'Zach', 'Billison')
# Вывод строки #798: (3065, 'Winna', 'Brusle')
# Вывод строки #799: (3066, 'Renell', 'Bellocht')
# Вывод строки #800: (3070, 'Malissia', 'Minthorpe')
# Вывод строки #801: (3081, 'Dodi', 'Volker')
# Вывод строки #802: (3084, 'Birgit', 'Dowers')
# Вывод строки #803: (3088, 'Hilarius', 'Trenbey')
# Вывод строки #804: (3089, 'Wood', 'Nathan')
# Вывод строки #805: (3091, 'Guenevere', 'Treffry')
# Вывод строки #806: (3093, 'Harwilll', 'Crimes')
# Вывод строки #807: (3095, 'Joachim', '')
# Вывод строки #808: (3097, 'Alessandro', 'Casley')
# Вывод строки #809: (3110, 'Fabien', 'Iacapucci')
# Вывод строки #810: (3112, 'Terri', 'Gornal')
# Вывод строки #811: (3117, 'Nisse', 'Marriage')
# Вывод строки #812: (3122, 'Cthrine', 'Orans')
# Вывод строки #813: (3124, 'Anastasie', 'Le Grand')
# Вывод строки #814: (3125, 'Krystyna', 'Scarasbrick')
# Вывод строки #815: (3128, 'Betteanne', 'Alldread')
# Вывод строки #816: (3129, 'Leola', 'Mandrier')
# Вывод строки #817: (3131, 'Sybilla', "O' Markey")
# Вывод строки #818: (3139, 'Pail', 'De Blasi')
# Вывод строки #819: (3145, 'Gar', 'Barnewille')
# Вывод строки #820: (3147, 'Bonnee', 'Farley')
# Вывод строки #821: (3148, 'Berky', 'Degoix')
# Вывод строки #822: (3149, 'Caprice', 'Pack')
# Вывод строки #823: (3152, 'Lettie', 'McGenis')
# Вывод строки #824: (3155, 'Tiphani', 'Fritz')
# Вывод строки #825: (3165, 'Vyky', 'Coppen')
# Вывод строки #826: (3171, 'Leif', '')
# Вывод строки #827: (3179, 'Jarid', 'Redwood')
# Вывод строки #828: (3184, 'Marlee', 'Brundle')
# Вывод строки #829: (3191, 'Bobbette', 'Amps')
# Вывод строки #830: (3192, 'Illa', 'Klemenz')
# Вывод строки #831: (3203, 'Swen', 'Merioth')
# Вывод строки #832: (3211, 'Betsy', 'Cosh')
# Вывод строки #833: (3213, 'Marcile', 'Vasiliev')
# Вывод строки #834: (3271, 'Daisi', 'Philip')
# Вывод строки #835: (3221, 'Brigid', 'Quigley')
# Вывод строки #836: (3229, 'Carrol', 'Gheorghie')
# Вывод строки #837: (3231, 'Cazzie', 'Gravell')
# Вывод строки #838: (3235, 'Leif', 'Woolfall')
# Вывод строки #839: (3242, 'Lib', 'Schohier')
# Вывод строки #840: (3250, 'Hussein', 'Ticic')
# Вывод строки #841: (3251, 'Cammie', 'Edridge')
# Вывод строки #842: (3252, 'Alexia', 'McTerrelly')
# Вывод строки #843: (3253, 'Bernadine', 'Shakeshaft')
# Вывод строки #844: (3267, 'Gerri', 'Prott')
# Вывод строки #845: (3285, 'Mendie', 'Teresi')
# Вывод строки #846: (3287, 'Marys', 'Vazquez')
# Вывод строки #847: (3290, 'Brandyn', 'Gain')
# Вывод строки #848: (3292, 'Hamlen', 'Slograve')
# Вывод строки #849: (3295, 'Cleavland', 'Karchowski')
# Вывод строки #850: (3296, 'Leontyne', 'Jackett')
# Вывод строки #851: (3299, 'Sybille', 'Ballsdon')
# Вывод строки #852: (3303, 'Ced', 'Cuell')
# Вывод строки #853: (3309, 'Christie', 'Bremeyer')
# Вывод строки #854: (3310, 'Bethany', 'Jarrell')
# Вывод строки #855: (3313, 'Kori', 'Antoshin')
# Вывод строки #856: (3318, 'Courtnay', 'Allmen')
# Вывод строки #857: (3319, 'Erda', '')
# Вывод строки #858: (3321, 'Ives', '')
# Вывод строки #859: (3326, 'Wes', 'Crotch')
# Вывод строки #860: (3341, 'Vitia', 'Crum')
# Вывод строки #861: (3344, 'Clerissa', 'Columbell')
# Вывод строки #862: (3347, 'Nichols', '')
# Вывод строки #863: (3348, 'Amanda', 'Hazeltine')
# Вывод строки #864: (3358, 'Fairlie', 'McGavin')
# Вывод строки #865: (3363, 'Orson', 'Tythacott')
# Вывод строки #866: (3370, 'Brant', 'Follis')
# Вывод строки #867: (3375, 'Thorsten', 'Gregon')
# Вывод строки #868: (3380, 'Abe', 'Ealam')
# Вывод строки #869: (3383, 'Dane', 'Swansbury')
# Вывод строки #870: (3386, 'Cliff', 'Nolin')
# Вывод строки #871: (3387, 'Shel', 'Duke')
# Вывод строки #872: (3398, 'Alberik', 'Looks')
# Вывод строки #873: (3407, 'Marven', 'Ditts')
# Вывод строки #874: (3414, 'Winnifred', 'Zima')
# Вывод строки #875: (3415, 'Alberik', 'Kelsey')
# Вывод строки #876: (3421, 'Ronalda', 'McGeechan')
# Вывод строки #877: (3424, 'Vale', 'Whittuck')
# Вывод строки #878: (3430, 'Augustus', 'Pickin')
# Вывод строки #879: (3439, 'Rubie', "O'Gorman")
# Вывод строки #880: (3441, 'Janelle', 'Ebbage')
# Вывод строки #881: (3445, 'Craggy', '')
# Вывод строки #882: (3449, 'Ilyssa', 'Hannabuss')
# Вывод строки #883: (3458, 'Alejandro', 'Shakelade')
# Вывод строки #884: (3461, 'Nigel', 'Izard')
# Вывод строки #885: (3465, 'Hadria', 'Pizer')
# Вывод строки #886: (3470, 'Catherina', 'Ricca')
# Вывод строки #887: (3471, 'Brita', 'Afonso')
# Вывод строки #888: (3472, 'Dionysus', 'McCarlie')
# Вывод строки #889: (3477, 'Jaquelin', 'Leek')
# Вывод строки #890: (3482, 'Roch', 'Rilston')
# Вывод строки #891: (3483, 'Emlyn', 'Burnel')
# Вывод строки #892: (3484, 'Hedi', 'Mowday')
# Вывод строки #893: (3485, 'Berthe', 'Ludwell')
# Вывод строки #894: (3497, 'Thia', "O'Day")
# Вывод строки #895: (3502, 'Wilfrid', 'Cleaves')
# Вывод строки #896: (3503, 'Tootsie', 'Rafter')
# Вывод строки #897: (3515, 'Leelah', 'Pynner')
# Вывод строки #898: (3521, 'Oneida', 'Olivia')
# Вывод строки #899: (3522, 'Lorri', 'Byrth')
# Вывод строки #900: (3526, 'Pail', 'Iacopini')
# Вывод строки #901: (3529, 'Austine', 'Kinny')
# Вывод строки #902: (3530, 'Erik', 'Kenneford')
# Вывод строки #903: (3531, 'Shannah', 'Pountain')
# Вывод строки #904: (3532, 'May', 'Birch')
# Вывод строки #905: (3533, 'Neale', 'Lowings')
# Вывод строки #906: (3534, 'Kacie', 'Stanbrooke')
# Вывод строки #907: (3543, 'Shanie', 'Zahor')
# Вывод строки #908: (3546, 'Hally', 'Pollie')
# Вывод строки #909: (3552, 'Ebeneser', 'Lowde')
# Вывод строки #910: (3559, 'Farra', 'Bails')
# Вывод строки #911: (3564, 'Sandy', 'Olford')
# Вывод строки #912: (3566, 'Bram', 'Pheasant')
# Вывод строки #913: (3567, 'Eileen', 'Ilchenko')
# Вывод строки #914: (3572, 'Willis', 'Tilston')
# Вывод строки #915: (3575, 'Kandace', 'Desesquelle')
# Вывод строки #916: (3585, 'Concordia', 'Lunbech')
# Вывод строки #917: (3588, 'Henrie', 'Beadman')
# Вывод строки #918: (3597, 'Giorgi', '')
# Вывод строки #919: (3598, 'Penny', 'McKirdy')
# Вывод строки #920: (3599, 'Lane', 'Maguire')
# Вывод строки #921: (3604, 'Findlay', 'Lubman')
# Вывод строки #922: (3610, 'Erl', 'Markel')
# Вывод строки #923: (3611, 'Uriah', 'Chantree')
# Вывод строки #924: (3614, 'Berkie', 'Gimber')
# Вывод строки #925: (3618, 'Evyn', 'Rouby')
# Вывод строки #926: (3623, 'Oren', 'Barwack')
# Вывод строки #927: (3625, 'Cammie', 'Rubinfeld')
# Вывод строки #928: (3627, 'Loren', 'Pischof')
# Вывод строки #929: (3630, 'Jeni', 'Heymes')
# Вывод строки #930: (3631, 'Mignonne', 'Barwood')
# Вывод строки #931: (3634, 'Clemence', 'Kornas')
# Вывод строки #932: (3637, 'Luigi', 'Edgeworth')
# Вывод строки #933: (3642, 'Ardith', 'Portigall')
# Вывод строки #934: (3644, 'Peder', 'Frotton')
# Вывод строки #935: (3652, 'Aldrich', 'Camble')
# Вывод строки #936: (3670, 'Leupold', 'Bernardini')
# Вывод строки #937: (3675, 'Samuele', 'Heller')
# Вывод строки #938: (3684, 'Jeffie', 'Mortell')
# Вывод строки #939: (3685, 'Solomon', 'Ruffles')
# Вывод строки #940: (3686, 'Shirley', 'Siss')
# Вывод строки #941: (3688, 'Fritz', 'Le Merchant')
# Вывод строки #942: (3692, 'Linea', 'Kubica')
# Вывод строки #943: (3693, 'Brenna', 'Raft')
# Вывод строки #944: (3695, 'Lem', 'Clamp')
# Вывод строки #945: (3704, 'Haslett', 'Ropars')
# Вывод строки #946: (3706, 'Darby', 'Jellett')
# Вывод строки #947: (3711, 'Ellene', 'Scinelli')
# Вывод строки #948: (3713, 'Cynthy', 'Snoad')
# Вывод строки #949: (3715, 'Willow', 'Rusbridge')
# Вывод строки #950: (3728, 'Chanda', 'Garmons')
# Вывод строки #951: (3738, 'Lucila', 'Smalls')
# Вывод строки #952: (3741, 'Mollee', 'Jeavons')
# Вывод строки #953: (3742, 'Veda', 'Faill')
# Вывод строки #954: (3746, 'Thaddeus', 'McLurg')
# Вывод строки #955: (3748, 'Maurise', 'Beal')
# Вывод строки #956: (3750, 'Yanaton', 'Beacom')
# Вывод строки #957: (3751, 'Millicent', 'Nacci')
# Вывод строки #958: (3752, 'Peta', 'Nunes Nabarro')
# Вывод строки #959: (3755, 'Stephen', 'Garnar')
# Вывод строки #960: (3763, 'Law', 'Jore')
# Вывод строки #961: (3769, 'Kerry', 'Wooldridge')
# Вывод строки #962: (3773, 'Wadsworth', 'Ruselin')
# Вывод строки #963: (3777, 'Letty', 'Giacobelli')
# Вывод строки #964: (3792, 'Ingunna', 'Loxston')
# Вывод строки #965: (3793, 'Shannen', 'Pitcock')
# Вывод строки #966: (3795, 'Taylor', 'Dollimore')
# Вывод строки #967: (3797, 'Kriste', 'Oldall')
# Вывод строки #968: (3802, 'Leila', 'Elcombe')
# Вывод строки #969: (3822, 'Conny', 'Speechley')
# Вывод строки #970: (3831, 'Kory', 'Mabson')
# Вывод строки #971: (3836, 'Jolee', 'Stearndale')
# Вывод строки #972: (3838, 'Mil', 'Clemitt')
# Вывод строки #973: (3839, 'Wallie', 'Christauffour')
# Вывод строки #974: (3854, 'Melody', 'Ivanilov')
# Вывод строки #975: (3860, 'Sheila-kathryn', 'Conklin')
# Вывод строки #976: (3868, 'Rica', 'Corrado')
# Вывод строки #977: (3872, 'Wilma', 'Budcock')
# Вывод строки #978: (3884, 'Sibley', 'Thirlwall')
# Вывод строки #979: (3888, 'Lusa', 'Vigers')
# Вывод строки #980: (3891, 'Amalea', 'Elcy')
# Вывод строки #981: (3893, 'Hadria', 'Moles')
# Вывод строки #982: (3895, 'Reginald', 'Struys')
# Вывод строки #983: (3897, 'Vanni', 'McAloren')
# Вывод строки #984: (3899, 'Rex', 'Gittings')
# Вывод строки #985: (3907, 'Adriana', 'Heam')
# Вывод строки #986: (3909, 'Micheil', 'McGeorge')
# Вывод строки #987: (3914, 'Izabel', 'Roelofs')
# Вывод строки #988: (3916, 'Myrtia', '')
# Вывод строки #989: (3924, 'Perry', 'Lampert')
# Вывод строки #990: (3928, 'Kristin', 'Way')
# Вывод строки #991: (3929, 'Jacqui', 'Fortnam')
# Вывод строки #992: (3933, 'Chiarra', 'Cops')
# Вывод строки #993: (3936, 'Rodd', 'Spare')
# Вывод строки #994: (3938, 'Dulcy', 'Wormleighton')
# Вывод строки #995: (3946, 'Wylie', 'FitzGilbert')
# Вывод строки #996: (3949, 'Costa', 'Sleightholm')
# Вывод строки #997: (3950, 'Alic', 'Juniper')
# Вывод строки #998: (3951, 'Ephrem', 'Hollerin')
# Вывод строки #999: (3953, 'Allyson', 'Simak')
# Вывод строки #1000: (3957, 'Bernice', 'Scotchforth')
# Вывод строки #1001: (3958, 'Pincus', 'Woodard')
# Вывод строки #1002: (3961, 'Gertie', 'Caser')
# Вывод строки #1003: (3962, 'Benoit', '')
# Вывод строки #1004: (3969, 'Randee', 'Penchen')
# Вывод строки #1005: (3970, 'Modesty', 'Storks')
# Вывод строки #1006: (3974, 'Misha', 'Ranklin')
# Вывод строки #1007: (3976, 'Gretel', 'Chrystal')
# Вывод строки #1008: (3989, 'Nicolas', 'Burdass')
# Вывод строки #1009: (3992, 'Germain', 'Tireman')
# Вывод строки #1010: (3997, 'Blanch', 'Nisuis')
# Вывод строки #1011: (3999, 'Patrizius', '')
# Вывод строки #1012: (168, 'Reggie', 'Broggetti')
# Вывод строки #1013: (454, 'Eugenie', 'Domenc')
# Вывод строки #1014: (548, 'Georgie', 'Cudbertson')
# Вывод строки #1015: (680, 'Gay', 'Pickersgill')
# Вывод строки #1016: (950, 'Bret', 'Ivakhnov')
# Вывод строки #1017: (1509, 'Sibley', 'Janek')
# Вывод строки #1018: (2000, 'Kain', 'Rene')
# Вывод строки #1019: (2021, 'Ulrica', 'Abelwhite')
# Вывод строки #1020: (2252, 'Darcey', 'Annis')
# Вывод строки #1021: (2426, 'Yancy', 'Ovett')
# Вывод строки #1022: (2854, 'Vikky', 'Dyde')
# Вывод строки #1023: (2963, 'Christin', 'Fricke')
# Вывод строки #1024: (2999, 'Rinaldo', 'Diggin')
# Вывод строки #1025: (3151, 'Thorn', 'Choffin')
# Вывод строки #1026: (3298, 'Christine', 'Baignard')
# Вывод строки #1027: (3322, 'Hew', 'Sworder')
# Вывод строки #1028: (3510, 'Jemima', 'Izaac')
# Вывод строки #1029: (3513, 'Enriqueta', 'Waterhowse')
# Вывод строки #1030: (3565, 'Charyl', 'Pottiphar')
# Вывод строки #1031: (3931, 'Kylie', 'Epine')
# Вывод строки #1032: (3935, 'Teodor', 'Alfonsini')

# %% [markdown]
# 7. Вывести всех клиентов из сферы 'IT' (ID, имя, фамилия), которые купили 2 из 5 продуктов с самой высокой list_price в продуктовой линейке Road.

# %%
query_7 = """
    with top5_products_by_price AS (
        SELECT product_id
        FROM product
        WHERE product_line = 'Road'
        ORDER BY list_price DESC
        LIMIT 5
        ), customer_buyed_products AS (
        SELECT 
            c.customer_id
            ,c.first_name
            ,c.last_name
            ,COUNT(DISTINCT p.product_id) AS top5_count
        FROM customer c
        JOIN orders o ON c.customer_id = o.customer_id 
        JOIN order_items oi ON o.order_id = oi.order_id 
        JOIN product p ON oi.product_id = p.product_id
        WHERE c.job_industry_category = 'IT'
            AND p.product_id IN (
                SELECT product_id
                FROM top5_products_by_price
            )
        GROUP BY c.customer_id, c.first_name, c. last_name
    )
    SELECT 
        c2.customer_id
        ,c2.first_name
        ,c2.last_name
    FROM customer_buyed_products c2
    WHERE top5_count >= 2;
"""

cur.execute(query_7)

resalt_output(cur.fetchall())
# Out:
# Вывод строки #1: (799, 'Harland', 'Spilisy')
# Вывод строки #2: (983, 'Shaylyn', 'Riggs')
# Вывод строки #3: (1683, 'Brenn', 'Bacon')
# Вывод строки #4: (1791, 'Ninon', 'Van Der Hoog')
# Вывод строки #5: (1820, 'Yard', 'Teeney')
# Вывод строки #6: (1887, 'Kynthia', 'Purcer')
# Вывод строки #7: (3406, 'Lucy', 'Lackmann')

# %% [markdown]
# 8. Вывести клиентов (ID, имя, фамилия, сфера деятельности) из сфер IT или Health, которые совершили не менее 3 подтвержденных заказов в период 2017-01-01 по 2017-03-01, и при этом их общий доход от этих заказов превышает 10 000 долларов.
# Разделить вывод на две группы (IT и Health) с помощью UNION.

# %%
query_8 = """
    with orders_with_conditions AS (
        SELECT
            o.customer_id
            ,COUNT(o.order_id) AS approved_count
            ,SUM(oi.quantity * oi.item_list_price_at_sale) AS total_sum
        FROM orders o
        JOIN order_items oi ON o.order_id = oi.order_id
        WHERE o.order_status = 'Approved'
            AND o.order_date BETWEEN '2017-01-01' AND '2017-03-01' 
        GROUP BY o.customer_id
        HAVING COUNT(o.order_id) >= 3
            AND SUM(oi.quantity * oi.item_list_price_at_sale) > 10000
    )
    SELECT
        c.customer_id
        ,c.first_name
        ,c.last_name
        ,c.job_industry_category 
    FROM customer c 
    JOIN orders_with_conditions owc ON c.customer_id = owc.customer_id
    WHERE c.job_industry_category = 'IT'

    UNION

    SELECT
        c2.customer_id
        ,c2.first_name
        ,c2.last_name
        ,c2.job_industry_category 
    FROM customer c2
    JOIN orders_with_conditions owc ON c2.customer_id = owc.customer_id
    WHERE c2.job_industry_category = 'Health'
    ORDER BY job_industry_category, customer_id;
"""

cur.execute(query_8)

resalt_output(cur.fetchall())
# Out:
# Вывод строки #1: (167, 'Nathalie', 'Tideswell', 'Health')
# Вывод строки #2: (173, 'Ebba', 'Hanselmann', 'Health')
# Вывод строки #3: (250, 'Kristofer', '', 'Health')
# Вывод строки #4: (394, 'Roanne', 'Cowthard', 'Health')
# Вывод строки #5: (424, 'Dennie', 'Eunson', 'Health')
# Вывод строки #6: (590, 'Ddene', 'Burleton', 'Health')
# Вывод строки #7: (607, 'Adelaida', 'Redmond', 'Health')
# Вывод строки #8: (695, 'Kevan', 'Kubal', 'Health')
# Вывод строки #9: (723, 'Madelina', 'Marte', 'Health')
# Вывод строки #10: (1154, 'Chase', 'Youd', 'Health')
# Вывод строки #11: (1291, 'Warner', 'Zuker', 'Health')
# Вывод строки #12: (1298, 'Guglielmo', 'Yele', 'Health')
# Вывод строки #13: (1389, 'Reina', 'Drever', 'Health')
# Вывод строки #14: (1533, 'Sonia', 'Rous', 'Health')
# Вывод строки #15: (1555, 'Marcello', 'Spenclay', 'Health')
# Вывод строки #16: (1762, 'Gaye', 'Steutly', 'Health')
# Вывод строки #17: (1913, 'Tamiko', 'Fergie', 'Health')
# Вывод строки #18: (1959, 'Arlen', 'Klossek', 'Health')
# Вывод строки #19: (2012, 'Maisey', 'Lavell', 'Health')
# Вывод строки #20: (2172, 'Emmery', 'Angrock', 'Health')
# Вывод строки #21: (2292, 'Christie', 'MacClure', 'Health')
# Вывод строки #22: (2353, 'Lyn', 'Luquet', 'Health')
# Вывод строки #23: (2788, 'Melantha', 'Pickburn', 'Health')
# Вывод строки #24: (2815, 'Emery', 'Carlett', 'Health')
# Вывод строки #25: (2992, 'Crystal', 'Assur', 'Health')
# Вывод строки #26: (3166, 'Bronson', 'Plowman', 'Health')
# Вывод строки #27: (64, 'Gerek', 'Yve', 'IT')
# Вывод строки #28: (255, 'Keeley', 'Kruger', 'IT')
# Вывод строки #29: (513, 'Kienan', 'Soar', 'IT')
# Вывод строки #30: (769, 'Cameron', 'Letherbury', 'IT')
# Вывод строки #31: (799, 'Harland', 'Spilisy', 'IT')
# Вывод строки #32: (1583, 'Krysta', "O' Reagan", 'IT')
# Вывод строки #33: (1791, 'Ninon', 'Van Der Hoog', 'IT')
# Вывод строки #34: (2039, 'Laureen', 'Blower', 'IT')
# Вывод строки #35: (2252, 'Darcey', 'Annis', 'IT')
# Вывод строки #36: (2932, 'Bradly', 'Deboick', 'IT')
# Вывод строки #37: (3169, 'Maxim', 'Chavrin', 'IT')
# Вывод строки #38: (3365, 'Karlens', 'Chaffyn', 'IT')

# %%
connection.close()
